# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys
sys.path.insert(0,"C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24")
print(sys.path)
# Out:
# ['C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24', 'C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24', 'C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24', 'C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24', 'C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24', 'C:\\Users\\darcey\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\darcey\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\darcey\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\darcey\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\fi
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
# Project modules
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission, Trajectory
from uuv_mission.control import PDController

sub = Submarine()
controller = PDController()
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("C:\\Users\\darcey\\OneDrive - Nexus365\\Eng\\Year 3\\B1\\B1CodingPractice1\\.venvs\\first_venv\\b1-coding-practical-mt24\\data\\mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
